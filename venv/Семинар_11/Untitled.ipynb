# %%
import numpy as np
import matplotlib.pyplot as plt

# Setting axis at the center
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
 
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
 
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
 
# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

def fx(x):
    return -12*(x**4)-18*(x**3) + 5*(x**2) + 10*x


x = np.linspace(-3, 3, 50)
y = [fx(n) for n in x]

plt.fill_between(x, y, where=(x < 0), color='green')
plt.fill_between(x, y, where=(x >= 0), color='red')


xmax = 0
ymax = 0
for i in range(1, 9):
    if y[i] > ymax:
        ymax = y
        xmax = x
        
max = 0
min = 0
for i in range(1, 9):
    if y[i] > 0:
        max = x
    if y[i] < 0:
        min = x

print(f"Вершина: ({xmax};{ymax})")

print(f"Функция > 0: ({max};{min})")
print(f"Функция < 0: ({max};{min})")

plt.plot(x, y)
# Out:
# Вершина: (0;0)
# Функция > 0: (0;[-3.         -2.87755102 -2.75510204 -2.63265306 -2.51020408 -2.3877551
#  -2.26530612 -2.14285714 -2.02040816 -1.89795918 -1.7755102  -1.65306122
#  -1.53061224 -1.40816327 -1.28571429 -1.16326531 -1.04081633 -0.91836735
#  -0.79591837 -0.67346939 -0.55102041 -0.42857143 -0.30612245 -0.18367347
#  -0.06122449  0.06122449  0.18367347  0.30612245  0.42857143  0.55102041
#   0.67346939  0.79591837  0.91836735  1.04081633  1.16326531  1.28571429
#   1.40816327  1.53061224  1.65306122  1.7755102   1.89795918  2.02040816
#   2.14285714  2.26530612  2.3877551   2.51020408  2.63265306  2.75510204
#   2.87755102  3.        ])
# Функция < 0: (0;[-3.         -2.87755102 -2.75510204 -2.63265306 -2.51020408 -2.3877551
#  -2.26530612 -2.14285714 -2.02040816 -1.89795918 -1.7755102  -1.65306122
#  -1.53061224 -1.40816327 -1.28571429 -1.16326531 -1.04081633 -0.91836735
#  -0.79591837 -0.67346939 -0.55102041 -0.42857143 -0.30612245 -0.18367347
# ...
